# %%
import pandas as pd
from pathlib import Path

# %%
azure_df = pd.read_csv('/content/azure_usage (1).csv')
external_df = pd.read_csv('/content/external_factors.csv.csv')

# %%
azure_df['date'] = pd.to_datetime(azure_df['date'])
external_df['date'] = pd.to_datetime(external_df['date'])

# %%
azure_df.ffill(inplace=True)
external_df.ffill(inplace=True)

# %%
azure_df.columns = azure_df.columns.str.lower().str.strip()
external_df.columns = external_df.columns.str.lower().str.strip()

# %%
merged_df = pd.merge(azure_df, external_df, on='date', how='left')

# %%
from pathlib import Path

output_dir = Path('../data/processed')
output_dir.mkdir(parents=True, exist_ok=True) # Create the directory if it doesn't exist

output_path = output_dir / 'cleaned_merged.csv'
merged_df.to_csv(output_path, index=False)

# %%
print(f"✅ Cleaned and merged dataset saved to {output_path}")
display(merged_df.head(10))
# Out:
# ✅ Cleaned and merged dataset saved to ../data/processed/cleaned_merged.csv
#         date          region resource_type  usage_cpu  usage_storage  \
# 0 2023-01-01         East US            VM         88           1959
# 1 2023-01-01         East US       Storage         92           1595
# 2 2023-01-01         East US     Container         70            621
# 3 2023-01-01         West US            VM         60           1982
# 4 2023-01-01         West US       Storage         85           1371
# 5 2023-01-01         West US     Container         52           1832
# 6 2023-01-01    North Europe            VM         73           1937
# 7 2023-01-01    North Europe       Storage         51           1715
# 8 2023-01-01    North Europe     Container         82            959
# 9 2023-01-01  Southeast Asia            VM         93           1356
#
#    users_active  economic_index  cloud_market_demand  holiday
# 0           470          104.97                 0.99        1
# ...
